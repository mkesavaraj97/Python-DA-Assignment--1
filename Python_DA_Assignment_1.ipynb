# %% [markdown]
# <a href="https://colab.research.google.com/github/mkesavaraj97/Python-DA-Assignment--1/blob/main/Python_DA_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
temperatures_w1 = np.array([22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9])

print(temperatures_w1)
# Out:
# [22.5 25.3 20.8 23.4 26.1 24.8 21.9]

# %%
temperatures_w1 = np.array([...])

# %%
print("Shape:", temperatures_w1.shape)
# Out:
# Shape: (1,)

# %%
print("Shape:", temperatures_w1.shape)
# Out:
# Shape: (1,)

# %%
print("Number of Elements:", temperatures_w1.size)
# Out:
# Number of Elements: 1

# %%
print("Shape:", temperatures_w1.shape)
print("Data Type:", temperatures_w1.dtype)
print("Number of Elements:", temperatures_w1.size)
# Out:
# Shape: (1,)
# Data Type: object
# Number of Elements: 1

# %%
temperatures_w1 = np.array([22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9])

temperatures_f = (temperatures_w1 * 9/5) + 32

print("Temperatures in Fahrenheit:")
print(temperatures_f)
# Out:
# Temperatures in Fahrenheit:
# [72.5  77.54 69.44 74.12 78.98 76.64 71.42]

# %%
maximum_temp = np.max(temperatures_w1)

print("Maximum Temperature:", maximum_temp)
# Out:
# Maximum Temperature: 26.1

# %%
minimum_temp = np.min(temperatures_w1)

print("Minimum Temperature:", minimum_temp)
# Out:
# Minimum Temperature: 20.8

# %%
mean_temp = np.mean(temperatures_w1)

print("Mean Temperature:", mean_temp)
# Out:
# Mean Temperature: 23.542857142857144

# %%
mean_temp = np.mean(temperatures_w1)

print("Mean Temperature:", mean_temp)
# Out:
# Mean Temperature: 23.542857142857144

# %% [markdown]
# Array Slicing and Indexing:

# %%
first_three_days = temperatures_w1[:3]

print("First Three Days:", first_three_days)
# Out:
# First Three Days: [22.5 25.3 20.8]

# %%
weekend = temperatures_w1[-2:]

print("Weekend Temperatures:", weekend)
# Out:
# Weekend Temperatures: [24.8 21.9]

# %%
middle_three_days = temperatures_w1[2:5]

print("Middle Three Days:", middle_three_days)
# Out:
# Middle Three Days: [20.8 23.4 26.1]

# %% [markdown]
# 2D Array

# %%
temperatures = np.array([
    [22.5, 25.3, 20.8, 23.4, 26.1, 24.8, 21.9],
    [19.2, 22.5, 21.3, 24.0, 23.5, 22.8, 20.1]])

print(temperatures)
# Out:
# [[22.5 25.3 20.8 23.4 26.1 24.8 21.9]
#  [19.2 22.5 21.3 24.  23.5 22.8 20.1]]

# %%
print("Shape:", temperatures.shape)
# Out:
# Shape: (2, 7)

# %%
print("Data Type:", temperatures.dtype)
# Out:
# Data Type: float64

# %%
print("Total Number of Elements:", temperatures.size)
# Out:
# Total Number of Elements: 14

# %%
week1 = temperatures[0]

print("Week 1:", week1)
# Out:
# Week 1: [22.5 25.3 20.8 23.4 26.1 24.8 21.9]

# %%
week2 = temperatures[1]

print("Week 2:", week2)
# Out:
# Week 2: [19.2 22.5 21.3 24.  23.5 22.8 20.1]

# %%
week2 = temperatures[1]

print("Week 2:", week2)
# Out:
# Week 2: [19.2 22.5 21.3 24.  23.5 22.8 20.1]

# %% [markdown]
# Pandas Series

# %%
import pandas as pd

# %%
marks = pd.Series(
    [95, 92, 89, 85, 80],
    index=['Rank1', 'Rank2', 'Rank3', 'Rank4', 'Rank5'])

print(marks)
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# Rank4    85
# Rank5    80
# dtype: int64

# %%
print(marks[0])
# Out:
# 95
# /tmp/ipykernel_1116/3296141910.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[0])

# %%
print(marks.iloc[0])
# Out:
# 95

# %%
print(marks.loc[['Rank1', 'Rank2', 'Rank3']])
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# dtype: int64

# %%
print(marks.iloc[2])
# Out:
# 89

# %%
print(marks[marks > 90])
# Out:
# Rank1    95
# Rank2    92
# dtype: int64

# %%
marks[marks > 90]
# Out:
# Rank1    95
# Rank2    92
# dtype: int64

# %% [markdown]
# Manipulating Series:

# %%
marks.loc['Rank1'] = 100

print(marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# Rank5     80
# dtype: int64

# %%
marks = marks.drop('Rank5')

print(marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# dtype: int64

# %%
cgpa = marks / 10

print(cgpa)
# Out:
# Rank1    10.0
# Rank2     9.2
# Rank3     8.9
# Rank4     8.5
# dtype: float64

# %% [markdown]
# Pandas DataFrame:

# %%
transactions = pd.DataFrame({
    'TransactionID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],

    'ProductCategory': [
        'Electronics', 'Clothing', 'Electronics', 'Furniture',
        'Clothing', 'Electronics', 'Furniture', 'Clothing',
        'Furniture', 'Electronics' ],
 'Region': [
        'North', 'South', 'North', 'East', 'West',
        'North', 'East', 'West', 'South', 'North' ],

    'Amount': [
        200, 150, 300, 450, 200,
        250, 300, 180, 350, 400 ]})

print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions.head())
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200

# %%
print(transactions.tail())
# Out:
#    TransactionID ProductCategory Region  Amount
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
print(transactions.shape)
# Out:
# (10, 4)

# %%
print(transactions.shape)
# Out:
# (10, 4)

# %%
print(transactions.dtypes)
# Out:
# TransactionID       int64
# ProductCategory    object
# Region             object
# Amount              int64
# dtype: object

# %%
print(transactions.dtypes)
# Out:
# TransactionID       int64
# ProductCategory    object
# Region             object
# Amount              int64
# dtype: object

# %%
print(transactions.iloc[:, -3:])
# Out:
#   ProductCategory Region  Amount
# 0     Electronics  North     200
# 1        Clothing  South     150
# 2     Electronics  North     300
# 3       Furniture   East     450
# 4        Clothing   West     200
# 5     Electronics  North     250
# 6       Furniture   East     300
# 7        Clothing   West     180
# 8       Furniture  South     350
# 9     Electronics  North     400

# %%
filtered = transactions[
    (transactions['Region'] == 'North') &
    (transactions['Amount'] > 200)
]

print(filtered)
# Out:
#    TransactionID ProductCategory Region  Amount
# 2            103     Electronics  North     300
# 5            106     Electronics  North     250
# 9            110     Electronics  North     400

# %%
print(transactions['ProductCategory'].value_counts())
# Out:
# ProductCategory
# Electronics    4
# Clothing       3
# Furniture      3
# Name: count, dtype: int64

# %%
print(transactions['Region'].unique())
# Out:
# ['North' 'South' 'East' 'West']

# %%
print(transactions.groupby('Region')['Amount'].mean())
# Out:
# Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %%
print(transactions.groupby('Region')['Amount'].mean())
# Out:
# Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %%
transactions['Discount'] = transactions['Amount'] * 0.10

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     150      15.0
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 8            109       Furniture  South     350      35.0
# 9            110     Electronics  North     400      40.0

# %%
transactions = transactions[
    transactions['TransactionID'] != 109]

# %%
print(transactions)
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     150      15.0
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 9            110     Electronics  North     400      40.0
